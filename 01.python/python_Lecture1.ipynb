# %% [markdown]
# #230407 파이썬1

# %%
3.14*10*10
# Out:
# 314.0

# %%
3.14**2
# Out:
# 9.8596

# %%
import math
math.sin(math.radians(30))
# Out:
# 0.49999999999999994

# %%
print('결과값은', 10, "입니다")
# Out:
# 결과값은 10 입니다

# %%
'나의'+'고양이'
# Out:
# '나의고양이'

# %%
radius=10
area=3.14*radius
print('반지름', radius, '인 원의 면적=',  area)
# Out:
# 반지름 10 인 원의 면적= 31.400000000000002

# %%
type(12.30)
# Out:
# float

# %%
type('hello')
# Out:
# str

# %%
x=1000
print('초깃값 x=', x)
x += 2
print('x+=2후의 x=', x)
x -= 2
print('x-=2 후의 x=', x)
# Out:
# 초깃값 x= 1000
# x+=2후의 x= 1002
# x-=2 후의 x= 1000

# %%
x=3.14
y = str(x)
print(y)
print(type(y))
# Out:
# 3.14
# <class 'str'>

# %%
a='''안녕하세요
권우빈입니다
'''

print(a)
# Out:
# 안녕하세요
# 권우빈입니다

# %%
name = "Harry Parter"
lower_name = name.lower()
lower_name
# Out:
# 'harry parter'

# %%
name = "Harry Parter"
new_name = name.replace('Parter', "Porter")

# %%
new_name
# Out:
# 'Harry Porter'

# %%
x=100
y=200
print(f'{x}와 {y}의 합={x+y}')
# Out:
# 100와 200의 합=300

# %%
py = 7.1234
print('테스트출력 %10.2f' % py) # %10.2 :  열칸을 할당시키겠다 소수점 둘재짜리까지
# Out:
# 테스트출력       7.12
